# %%
from model_face_recognition import *

# %%
model_face = ModelFaceRecognition("/home/alex/Documents/one_data_folder")

# %%
model_face.reduction_image(reduc_coeff=0.1)
# Out:
# ...
# Réduction de 24_09_06 Soirée Siamois: 100%|██████████| 321/321 [00:14<00:00, 21.78it/s]

# %%
model_face.detect_and_extract_faces()
# Out:
# ...
# Traitement de 24_09_06 Soirée Siamois: 100%|██████████| 321/321 [00:15<00:00, 21.29it/s]

# %%
model_face.cluster_faces()
# Out:
# Nombre de clusters trouvés (hors -1) : 51

# %%
model_face.visualize_clusters(nb_affichage=15)
# Out:
# Clusters ignorés (outliers) : 97
# Clusters valides : 51
